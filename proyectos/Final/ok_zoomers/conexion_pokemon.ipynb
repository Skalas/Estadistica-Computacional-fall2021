# %%
import pandas as pd
import pickle
import psycopg2
import psycopg2.extras
import json
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import warnings

# %%
connection = psycopg2.connect(user="postgres",
  password="pokemon",
  host="0.0.0.0",
  port="5432")
cursor = connection.cursor()

cur = connection.cursor(cursor_factory=psycopg2.extras.NamedTupleCursor)
cur.execute("SELECT * FROM pokemon_;")
results = cur.fetchall()
# cur.close()
results = json.dumps([x._asdict() for x in results], default=str)
pokemon = pd.read_json(results)

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
pokemon.head()
# Out:
#                                   abilities  against_bug  against_dark  \
# 0               'Volt Absorb', 'Quick Feet'          1.0           1.0
# 1        'Pickup', 'Gluttony', 'Quick Feet'          1.0           1.0
# 2  'Liquid Ooze', 'Sticky Hold', 'Gluttony'          0.5           1.0
# 3   'Bulletproof', 'Soundproof', 'Overcoat'          1.0           1.0
# 4      'Water Absorb', 'Damp', 'Swift Swim'          0.5           0.5
#
#    against_dragon  against_electric  against_fairy  against_fight  \
# 0             1.0               0.5            1.0            1.0
# 1             1.0               1.0            1.0            2.0
# 2             1.0               1.0            0.5            0.5
# 3             2.0               0.5            2.0            1.0
# 4             1.0               2.0            2.0            1.0
#
#    against_fire  against_flying  against_ghost  ...  percentage_male  \
# 0           1.0             0.5            1.0  ...             88.1
# 1           1.0             1.0            0.0  ...             50.0
# 2           1.0             1.0            1.0  ...             50.0
# 3           0.5             1.0            1.0  ...             50.0
# 4           0.5             2.0            1.0  ...             50.0
#
#    pokedex_number  sp_attack  sp_defense  speed     type1     type2  \
# 0             135        110          95    130  electric      None
# 1             264         50          61    100    normal      None
# 2             317         73          83     55    poison      None
# 3             782         45          45     45    dragon      None
# 4              62         70          90     70     water  fighting
#
#    weight_kg  generation  is_legendary
# 0       24.5           1             0
# 1       32.5           3             0
# 2       80.0           3             0
# 3       29.7           7             0
# 4       54.0           1             0
#
# [5 rows x 41 columns]

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          800 non-null    object
#  1   against_bug        800 non-null    float64
#  2   against_dark       800 non-null    float64
#  3   against_dragon     800 non-null    float64
#  4   against_electric   800 non-null    float64
#  5   against_fairy      800 non-null    float64
#  6   against_fight      800 non-null    float64
#  7   against_fire       800 non-null    float64
#  8   against_flying     800 non-null    float64
#  9   against_ghost      800 non-null    float64
#  10  against_grass      800 non-null    float64
#  11  against_ground     800 non-null    float64
#  12  against_ice        800 non-null    float64
#  13  against_normal     800 non-null    float64
#  14  against_poison     800 non-null    float64
#  15  against_psychic    800 non-null    float64
#  16  against_rock       800 non-null    float64
#  17  against_steel      800 non-null    float64
#  18  against_water      800 non-null    float64
#  19  attack             800 non-null    int64
#  20  base_egg_steps     800 non-null    int64
#  21  base_happiness     800 non-null    int64
#  22  base_total         800 non-null    int64
#  23  capture_rate       800 non-null    int64
#  24  classfication      800 non-null    object
#  25  defense            800 non-null    int64
#  26  experience_growth  800 non-null    int64
#  27  height_m           780 non-null    float64
#  28  hp                 800 non-null    int64
#  29  japanese_name      800 non-null    object
#  30  name               800 non-null    object
#  31  percentage_male    703 non-null    float64
#  32  pokedex_number     800 non-null    int64
#  33  sp_attack          800 non-null    int64
#  34  sp_defense         800 non-null    int64
#  35  speed              800 non-null    int64
#  36  type1              800 non-null    object
#  37  type2              416 non-null    object
#  38  weight_kg          780 non-null    float64
#  39  generation         800 non-null    int64
#  40  is_legendary       800 non-null    int64
# dtypes: float64(21), int64(14), object(6)
# memory usage: 256.4+ KB
